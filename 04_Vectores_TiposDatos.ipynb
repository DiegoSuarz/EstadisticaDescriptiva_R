# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - c() : para definir un vector
# - scan(): para definir un vector por consola
# - fix(x): para modificar visualmente un vector
# - rep(a,n): para definir un vector constante que contiene el dato repetido n veces

# %%
c( 2,TRUE, 3.5)
# Out:
# [1] 2.0 1.0 3.5

# %%
c(4,5.67, "Juan Gabriel")
# Out:
# [1] "4"            "5.67"         "Juan Gabriel"

# %%
scan() # para leer datos desde la consola
# Out:
# numeric(0)

# %%
x <- c(1,2,3,4,5)

# %%
fix(x)

# %%
x
# Out:
# [1] 1 2 3 4 7 8

# %%
y <- scan()
y
# Out:
# numeric(0)

# %%
vec <- c(16,0,1,20,1,7,88,5,1,9)

# %%
fix(vec)

# %%
vec
# Out:
#  [1] 16  0  1 20 55  7 88  5  1  9

# %%
rep("Mates",7)
# Out:
# [1] "Mates" "Mates" "Mates" "Mates" "Mates" "Mates" "Mates"

# %%
rep("05-09-1991",10)
# Out:
#  [1] "05-09-1991" "05-09-1991" "05-09-1991" "05-09-1991" "05-09-1991"
#  [6] "05-09-1991" "05-09-1991" "05-09-1991" "05-09-1991" "05-09-1991"

# %%
scan(dec = "," , what = "character")
