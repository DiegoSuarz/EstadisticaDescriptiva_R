# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = c(1,5,-2,-7,8,-3,4,-9)
x
# Out:
# [1]  1  5 -2 -7  8 -3  4 -9

# %%
L = list(nombre = "temperaturas", datos = x, media = mean(x), sumas = cumsum(x))
L
# Out:
# $nombre
# [1] "temperaturas"
#
# $datos
# [1]  1  5 -2 -7  8 -3  4 -9
#
# $media
# [1] -0.375
#
# $sumas
# [1]  1  6  4 -3  5  2  6 -3

# %%
L$media
# Out:
# [1] -0.375

# %%
L$nombre
# Out:
# [1] "temperaturas"

# %%
L$sumas
# Out:
# [1]  1  6  4 -3  5  2  6 -3

# %%
L[[3]]
# Out:
# [1] -0.375

# %%
L[[2]]
# Out:
# [1]  1  5 -2 -7  8 -3  4 -9

# %%
L[[1]]
# Out:
# [1] "temperaturas"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
names(L)
# Out:
# [1] "nombre" "datos"  "media"  "sumas"

# %%
str(L)
# Out:
# List of 4
#  $ nombre: chr "temperaturas"
#  $ datos : num [1:8] 1 5 -2 -7 8 -3 4 -9
#  $ media : num -0.375
#  $ sumas : num [1:8] 1 6 4 -3 5 2 6 -3

# %%
summary(lm(c(1,2,3,4,5) ~ c(1,2,3,6)))
# Out:
# Error in model.frame.default(formula = c(1, 2, 3, 4, 5) ~ c(1, 2, 3, 6), : las longitudes variables difieren (encontradas para 'c(1, 2, 3, 6)')
# Traceback:
#
# 1. lm(c(1, 2, 3, 4, 5) ~ c(1, 2, 3, 6))
# 2. eval(mf, parent.frame())
# 3. eval(mf, parent.frame())
# 4. stats::model.frame(formula = c(1, 2, 3, 4, 5) ~ c(1, 2, 3, 6),
#  .     drop.unused.levels = TRUE)
# 5. model.frame.default(formula = c(1, 2, 3, 4, 5) ~ c(1, 2, 3, 6),
#  .     drop.unused.levels = TRUE)
# 6. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "las longitudes variables difieren (encontradas para 'c(1, 2, 3, 6)')",
#  .     base::quote(model.frame.default(formula = c(1, 2, 3, 4, 5) ~
#  .         c(1, 2, 3, 6), drop.unused.levels = TRUE)))

# %%
reg <- lm(c(1,2,3,4) ~ c(1,2,3,6))
reg$coefficients
# Out:
#   (Intercept) c(1, 2, 3, 6)
#     0.7857143     0.5714286
