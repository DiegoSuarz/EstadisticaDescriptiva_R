# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Beb_Energ = read.table("base de datos/EnergyDrink", header = TRUE)
head(Beb_Energ,5)
# Out:
#   estudio      bebe sexo
# 1 Informatica  No   Mujer
# 2 Mates        No   Hombre
# 3 Industriales Si   Mujer
# 4 Informatica  Si   Hombre
# 5 Industriales No   Mujer

# %%
str(Beb_Energ)
# Out:
# 'data.frame':	122 obs. of  3 variables:
#  $ estudio: chr  "Informatica" "Mates" "Industriales" "Informatica" ...
#  $ bebe   : chr  "No" "No" "Si" "Si" ...
#  $ sexo   : chr  "Mujer" "Hombre" "Mujer" "Hombre" ...

# %%
summary(Beb_Energ)
# Out:
#    estudio              bebe               sexo
#  Length:122         Length:122         Length:122
#  Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character

# %%
summary(Beb_Energ)[,2] #Para obtener solo los valores de la segunda columna
# Out:
#
# "Length:122        " "Class :character  " "Mode  :character  "

# %%
apply(Beb_Energ, MARGIN = 2, FUN = table) #Para obtener la frecuencia de cada valor en cada columna
# Out:
# $estudio
#
# Industriales  Informatica        Mates   Telematica
#           37           53           16           16
#
# $bebe
#
# No Si
# 97 25
#
# $sexo
#
# Hombre  Mujer
#     83     39

# %%
apply(Beb_Energ, MARGIN = 2, FUN = table)$sexo #Para obtener la frecuencia de cada valor en la columna sexo
# Out:
# Hombre  Mujer
#     83     39

# %%
table(Beb_Energ$sexo) #Para obtener la frecuencia de cada valor en la columna sexo
# Out:
# Hombre  Mujer
#     83     39

# %%
table(Beb_Energ)
# Out:
# , , sexo = Hombre
#
#               bebe
# estudio        No Si
#   Industriales 19  6
#   Informatica  30  7
#   Mates         8  1
#   Telematica   10  2
#
# , , sexo = Mujer
#
#               bebe
# estudio        No Si
#   Industriales 10  2
#   Informatica  11  5
#   Mates         6  1
#   Telematica    3  1

# %%
table(Beb_Energ[c(1,3)]) #Para obtener la frecuencia de cada valor en las columnas 1 y 3
# Out:
#               sexo
# estudio        Hombre Mujer
#   Industriales     25    12
#   Informatica      37    16
#   Mates             9     7
#   Telematica       12     4

# %%
ftable(Beb_Energ) #Para obtener la frecuencia de cada valor en todas las columnas
# Out:
#                   sexo Hombre Mujer
# estudio      bebe
# Industriales No            19    10
#              Si             6     2
# Informatica  No            30    11
#              Si             7     5
# Mates        No             8     6
#              Si             1     1
# Telematica   No            10     3
#              Si             2     1
