# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nombres = c("Juan", "Antonio", "Ricardo", "Juan", "Juan", "Maria", "Maria")
nombres
# Out:
# [1] "Juan"    "Antonio" "Ricardo" "Juan"    "Juan"    "Maria"   "Maria"

# %%
nombres.factor = factor(nombres)
nombres.factor
# Out:
# [1] Juan    Antonio Ricardo Juan    Juan    Maria   Maria
# Levels: Antonio Juan Maria Ricardo

# %%
gender = c("M", "H", "H", "M", "M", "M", "M", "H", "H")
gender.fact = factor(gender)
gender.fact
# Out:
# [1] M H H M M M M H H
# Levels: H M

# %%
gender.fact2 = as.factor(gender)
gender.fact2
# Out:
# [1] M H H M M M M H H
# Levels: H M

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
gender.fact3 = factor(gender, levels= c("M","H","B"))
gender.fact3
# Out:
# [1] M H H M M M M H H
# Levels: M H B

# %%
gender.fact4 = factor(gender, levels= c("M","H","B"), labels = c("Mujer", "Hombre", "Hermafrodita"))
gender.fact4
# Out:
# [1] Mujer  Hombre Hombre Mujer  Mujer  Mujer  Mujer  Hombre Hombre
# Levels: Mujer Hombre Hermafrodita

# %%
levels(gender.fact)
# Out:
# [1] "H" "M"

# %%
levels(gender.fact4)
# Out:
# [1] "Mujer"        "Hombre"       "Hermafrodita"

# %%
levels(gender.fact4) = c("Femenino", "Masculino", "Hibrido")
gender.fact4
# Out:
# [1] Femenino  Masculino Masculino Femenino  Femenino  Femenino  Femenino
# [8] Masculino Masculino
# Levels: Femenino Masculino Hibrido

# %%
notas = c(1,4,3,2,3,2,4,3,2,3,4,2,3,4)
notas
# Out:
#  [1] 1 4 3 2 3 2 4 3 2 3 4 2 3 4

# %%
notas.factor = factor(notas)
notas.factor
# Out:
#  [1] 1 4 3 2 3 2 4 3 2 3 4 2 3 4
# Levels: 1 2 3 4

# %%
levels(notas.factor)
# Out:
# [1] "1" "2" "3" "4"

# %%
levels(notas.factor)= c("Suspendido", "Suficiente", "Notable", "Excelente")
notas.factor
# Out:
#  [1] Suspendido Excelente  Notable    Suficiente Notable    Suficiente
#  [7] Excelente  Notable    Suficiente Notable    Excelente  Suficiente
# [13] Notable    Excelente
# Levels: Suspendido Suficiente Notable Excelente

# %%
levels(notas.factor) = c("Suspendido", "Aprobado", "Aprobado", "Aprobado")
notas.factor
# Out:
#  [1] Suspendido Aprobado   Aprobado   Aprobado   Aprobado   Aprobado
#  [7] Aprobado   Aprobado   Aprobado   Aprobado   Aprobado   Aprobado
# [13] Aprobado   Aprobado
# Levels: Suspendido Aprobado

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ordered(notas, labels = c("Sus", "Suf", "Not", "Exc"))
# Out:
#  [1] Sus Exc Not Suf Not Suf Exc Not Suf Not Exc Suf Not Exc
# Levels: Sus < Suf < Not < Exc
